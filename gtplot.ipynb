# %%
import numpy as np

from graphtools import *
from vectools import *

# %%
max_depth = 3
p=4

vertex_sizes = [600,400,50,20]
o_w = [4,3.5,1.6]
e_w = [7,5,3,1.2]
x_len = [3,6,9]


#fig, axes = plt.subplots(1, max_depth, figsize=(20, 6))  # adjust figsize as needed

fig, axes = plt.subplots(nrows=1, ncols=max_depth, figsize=(sum(x_len), 6),
                         gridspec_kw={'width_ratios': x_len})


# Loop over each subplot in the grid:
for j in range(1,max_depth+1):
    # For demonstration, create tree positions and a tree graph for each subplot
    X = [p]*j
    positions = tree_coords(X, xd=1, yd=1)
    tree = generate_good_tree(X)  # Replace with your actual tree generation
    tree_copy = tree.deep_copy()
    tree_size =  len(tree_copy.nodes)
    bot_layer = [int(node.index) for node in tree.nodes if node.degree == 1]
    copy_bot_layer = [int(leaf) + tree_size for leaf in bot_layer]

    gt_illusion = ConnectedGraph(nodes = tree_copy.nodes | shift_graph(tree, tree_size ).nodes )
    
    # Plot the tree on the corresponding Axes
    ax = pl_graph(axes[j-1], gt_illusion, positions= glued_tree_coords(X,xd=x_len[j-1] ,yd=4,spacing=0), 
                    vertex_size=vertex_sizes[j-1],outline_weight = o_w[j-1], edge_weight=e_w[j-1],margin=.5)


# Adjust layout to prevent overlap and show the combined figure:
plt.tight_layout()
plt.show()

# %%
max_depth = 3
p=3

vertex_sizes = [600,400,300]
o_w = [4,3.5,3]
e_w = [7,5,4]
x_len = [3,6,9]


#fig, axes = plt.subplots(1, max_depth, figsize=(20, 6))  # adjust figsize as needed

fig, axes = plt.subplots(nrows=1, ncols=max_depth, figsize=(sum(x_len), 6),
                         gridspec_kw={'width_ratios': x_len})


# Loop over each subplot in the grid:
for j in range(1,max_depth+1):
    # For demonstration, create tree positions and a tree graph for each subplot
    X = [p]*j
    positions = tree_coords(X, xd=1, yd=1)
    tree = generate_good_tree(X)  # Replace with your actual tree generation
    tree_copy = tree.deep_copy()
    tree_size =  len(tree_copy.nodes)
    bot_layer = [int(node.index) for node in tree.nodes if node.degree == 1]
    copy_bot_layer = [int(leaf) + tree_size for leaf in bot_layer]

    gt_illusion = ConnectedGraph(nodes = tree_copy.nodes | shift_graph(tree, tree_size ).nodes )
    
    # Plot the tree on the corresponding Axes
    ax = pl_graph(axes[j-1], gt_illusion, positions= glued_tree_coords(X,xd=x_len[j-1] ,yd=4,spacing=0), 
                    vertex_size=vertex_sizes[j-1],outline_weight = o_w[j-1], edge_weight=e_w[j-1],margin=.5)


# Adjust layout to prevent overlap and show the combined figure:
plt.tight_layout()
plt.show()

# %%
max_depth = 3
p=2

vertex_sizes = [600,400,350]
o_w = [4,3.5,3]
e_w = [7,5,4]
x_len = [3,6,9]


#fig, axes = plt.subplots(1, max_depth, figsize=(20, 6))  # adjust figsize as needed

fig, axes = plt.subplots(nrows=1, ncols=max_depth, figsize=(sum(x_len), 6),
                         gridspec_kw={'width_ratios': x_len})


# Loop over each subplot in the grid:
for j in range(1,max_depth+1):
    # For demonstration, create tree positions and a tree graph for each subplot
    X = [p]*j
    positions = tree_coords(X, xd=1, yd=1)
    tree = generate_good_tree(X)  # Replace with your actual tree generation
    tree_copy = tree.deep_copy()
    tree_size =  len(tree_copy.nodes)
    bot_layer = [int(node.index) for node in tree.nodes if node.degree == 1]
    copy_bot_layer = [int(leaf) + tree_size for leaf in bot_layer]

    gt_illusion = ConnectedGraph(nodes = tree_copy.nodes | shift_graph(tree, tree_size ).nodes )
    
    # Plot the tree on the corresponding Axes
    ax = pl_graph(axes[j-1], gt_illusion, positions= glued_tree_coords(X,xd=x_len[j-1] ,yd=4,spacing=0), 
                    vertex_size=vertex_sizes[j-1],outline_weight = o_w[j-1], edge_weight=e_w[j-1],margin=.5)


# Adjust layout to prevent overlap and show the combined figure:
plt.tight_layout()
plt.show()

# %%
###################################
# 1) Define all parameter sets
###################################
# -- First row --
max_depth_1 = 3
p_1 = 4
vertex_sizes_1 = [600, 400, 50]  # We'll only use 3 values for 3 subplots
o_w_1 = [4, 3.5, 1.6]
e_w_1 = [7, 5, 3]
x_len_1 = [3, 6, 9]

# -- Second row --
max_depth_2 = 3
p_2 = 3
vertex_sizes_2 = [600, 400, 300]
o_w_2 = [4, 3.5, 3]
e_w_2 = [7, 5, 4]
x_len_2 = [3, 6, 9]

# -- Third row --
max_depth_3 = 3
p_3 = 2
vertex_sizes_3 = [600, 400, 350]
o_w_3 = [4, 3.5, 3]
e_w_3 = [7, 5, 4]
x_len_3 = [3, 6, 9]

###################################
# 2) Create one figure with 3 rows × 3 columns
###################################
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(sum(x_len_1), 18),gridspec_kw={'width_ratios': x_len})

###################################
# 3) First row (parameters for p=4)
###################################
for j in range(max_depth_1):
    X = [p_1] * (j + 1)
    # Generate / clone / shift your tree as in your code
    positions_1 = tree_coords(X, xd=1, yd=1)
    tree_1 = generate_good_tree(X)  
    tree_copy_1 = tree_1.deep_copy()
    tree_size_1 = len(tree_copy_1.nodes)

    bot_layer_1 = [int(node.index) for node in tree_1.nodes if node.degree == 1]
    copy_bot_layer_1 = [leaf + tree_size_1 for leaf in bot_layer_1]

    gt_illusion_1 = ConnectedGraph(
        nodes=tree_copy_1.nodes | shift_graph(tree_1, tree_size_1).nodes
    )

    # Plot on axes[0, j] (row 0, column j)
    pl_graph(
        axes[2, j], 
        gt_illusion_1, 
        positions=glued_tree_coords(X, xd=x_len_1[j], yd=4, spacing=0), 
        vertex_size=vertex_sizes_1[j],
        outline_weight=o_w_1[j],
        edge_weight=e_w_1[j],
        margin=.5
    )

###################################
# 4) Second row (parameters for p=3)
###################################
for j in range(max_depth_2):
    X = [p_2] * (j + 1)
    positions_2 = tree_coords(X, xd=1, yd=1)
    tree_2 = generate_good_tree(X)
    tree_copy_2 = tree_2.deep_copy()
    tree_size_2 = len(tree_copy_2.nodes)

    bot_layer_2 = [int(node.index) for node in tree_2.nodes if node.degree == 1]
    copy_bot_layer_2 = [leaf + tree_size_2 for leaf in bot_layer_2]

    gt_illusion_2 = ConnectedGraph(
        nodes=tree_copy_2.nodes | shift_graph(tree_2, tree_size_2).nodes
    )

    pl_graph(
        axes[1, j], 
        gt_illusion_2, 
        positions=glued_tree_coords(X, xd=x_len_2[j], yd=4, spacing=0),
        vertex_size=vertex_sizes_2[j],
        outline_weight=o_w_2[j],
        edge_weight=e_w_2[j],
        margin=.5
    )

###################################
# 5) Third row (parameters for p=2)
###################################
for j in range(max_depth_3):
    X = [p_3] * (j + 1)
    positions_3 = tree_coords(X, xd=1, yd=1)
    tree_3 = generate_good_tree(X)
    tree_copy_3 = tree_3.deep_copy()
    tree_size_3 = len(tree_copy_3.nodes)

    bot_layer_3 = [int(node.index) for node in tree_3.nodes if node.degree == 1]
    copy_bot_layer_3 = [leaf + tree_size_3 for leaf in bot_layer_3]

    gt_illusion_3 = ConnectedGraph(
        nodes=tree_copy_3.nodes | shift_graph(tree_3, tree_size_3).nodes
    )

    pl_graph(
        axes[0, j], 
        gt_illusion_3, 
        positions=glued_tree_coords(X, xd=x_len_3[j], yd=4, spacing=0),
        vertex_size=vertex_sizes_3[j],
        outline_weight=o_w_3[j],
        edge_weight=e_w_3[j],
        margin=.5
    )

###################################
# 6) Final layout adjustments
###################################
plt.subplots_adjust(hspace=0)
plt.tight_layout()
plt.savefig("varioustrees.pdf",format="pdf")
plt.show()
